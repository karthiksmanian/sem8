# %%
import pandas as pd

# %%
df = pd.read_csv("Z:/DATA-VIS/ps1/TCSNS.csv")

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2013-01-14  659.500000  674.224976  653.674988  667.250000  532.850403
# 1  2013-01-15  695.000000  700.000000  663.500000  668.724976  534.028076
# 2  2013-01-16  668.450012  677.500000  654.500000  673.875000  538.140991
# 3  2013-01-17  674.849976  685.900024  671.500000  681.000000  543.830872
# 4  2013-01-18  681.250000  683.025024  669.025024  675.500000  539.438477
#
#       Volume
# 0  5790224.0
# 1  8262978.0
# 2  4109492.0
# 3  3028544.0
# 4  1440470.0

# %%
import matplotlib.pyplot as plt

# %%
df = df[['Date','Close']]

# %%
df['date'] = pd.to_datetime(df['date'],infer_datetime_format=True)
df = df.set_index(['date'])
# Out:
# C:\Users\TEMP.CS2K16\AppData\Local\Temp\ipykernel_2344\2465206814.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['date'] = pd.to_datetime(df['date'],infer_datetime_format=True)

# %%
df.head()
# Out:
#                  close
# date
# 2013-01-14  667.250000
# 2013-01-15  668.724976
# 2013-01-16  673.875000
# 2013-01-17  681.000000
# 2013-01-18  675.500000

# %%
rolling_mean = df.rolling(window=12).mean()
rolling_std = df.rolling(window=12).std()
plt.figure(figsize = (10,6))
plt.plot(df, color='cornflowerblue', label='Original')
plt.plot(rolling_mean, color='firebrick', label='Rolling Mean')
plt.plot(rolling_std, color='limegreen', label='Rolling Std')
plt.xlabel('Date', size = 12)
plt.ylabel('Closing Price', size  = 12)
plt.legend(loc = 'upper left')
plt.title('Rolling Statistics', size = 14)
plt.show()
